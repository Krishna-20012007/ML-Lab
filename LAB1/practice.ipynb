# %% [markdown]
# # excercise 1

# %%
import math
import statistics
import numpy as np
from scipy import linalg

# %%
import math
x=float(input("enter x:"))
print("Floor: ",math.floor(x))
print("Ceil: ",math.ceil(x))
print("Square root: ",math.sqrt(x))
print("Integer square root: ",math.isqrt(78))
print("GCD: ",math.gcd(24,36))
# Out:
# enter x: 78.56
# Floor:  78
# Ceil:  79
# Square root:  8.863407922464136
# Integer square root:  8
# GCD:  12

# %%
x =10
y =20
if x>y:
    print("if stmt executed")
else:
    print("else stmt executed")
# Out:
# else stmt executed

# %%
x = 40
y = 20
z = 50
if x>y and x>z:
     print("x is greater")
elif y>x and y>z:
    print("y is greater")
else:
    print("z is greater")
# Out:
# z is greater

# %%
x = 10
while x>5:
 print(x)
 x = x-1
 print("while loop executed")
# Out:
# 10
# while loop executed
# 9
# while loop executed
# 8
# while loop executed
# 7
# while loop executed
# 6
# while loop executed

# %%
x = 10
while x>5:
    print(x)
    x = x-1
    print("while loop executed")
else:
   print("Inside else")
# Out:
# 10
# while loop executed
# 9
# while loop executed
# 8
# while loop executed
# 7
# while loop executed
# 6
# while loop executed
# Inside else

# %%
x = 5
for i in range(x):
    print(x)
    print("for loop executed")
# Out:
# 5
# for loop executed
# 5
# for loop executed
# 5
# for loop executed
# 5
# for loop executed
# 5
# for loop executed

# %%
age=int(input("Whats you age? "))
print(f'Your age is {age}')
# Out:
# Whats you age?  19
# Your age is 19

# %%
age=int(input("Whats you age? "))
print("Your age is ",age)
# Out:
# Whats you age?  19
# Your age is  19
